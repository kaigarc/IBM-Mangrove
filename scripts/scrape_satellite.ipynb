# %%
# !pip install --upgrade -q landsatxplore

# %%
pip install fastapi

# %%
pip install kaleido
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 6.8 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires python-multipart, which is not installed.
# ...

# %%
pip install python-multipart

# %%
pip install uvicorn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.1 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# ...

# %%
from landsatxplore.api import API

# Your USGS  credentials
username = 'pruhtopia'
password = 'Sanika1077!!'

# Initialize a new API instance
api = API(username, password)

# Perform a request
response = api.request(endpoint="dataset-catalogs")
print(response)
# Out:
# {'EE': 'EarthExplorer', 'GV': 'GloVis', 'HDDS': 'HDDS Explorer'}

# %%
import json
from landsatxplore.api import API
from landsatxplore.earthexplorer import EarthExplorer

# Initialize a new API instance and get an access key
api = API(username, password)

# Search for Landsat TM scenes
scenes = api.search(
    dataset='landsat_tm_c2_l1',
    latitude=25,
    longitude=-79,
    start_date='2010-01-01',
    end_date='2020-12-30',
    max_cloud_cover=50
)

print(f"{len(scenes)} scenes found.")

# Process the result
if scenes:
    first_scene = scenes[0]
    print(first_scene['landsat_scene_id'])
    print("Downloading the first scene...")
    ee = EarthExplorer(username, password)
    ee.download(first_scene['landsat_scene_id'], output_dir='/content/')

    print("First scene downloaded.")
else:
    print("No scenes found.")

api.logout()
# Out:
# 9 scenes found.
# LT50140432011147CHM02
# ...
# Download failed with dataset id 1 of 3. Re-trying with the next one.
# None of the archived ids succeeded! Update necessary!
# ---------------------------------------------------------------------------
# EarthExplorerError                        Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/landsatxplore/earthexplorer.py in download(self, identifier, output_dir, dataset, timeout, skip, overwrite)
#     195                 )
# --> 196                 filename = self._download(
#     197                     url, output_dir, timeout=timeout, skip=skip, overwrite=overwrite
#
# /usr/local/lib/python3.10/dist-packages/landsatxplore/earthexplorer.py in _download(self, url, output_dir, timeout, chunk_size, skip, overwrite)
#      85             if error_msg:
# ---> 86                 raise EarthExplorerError(error_msg)
#      87             download_url = r.json().get("url")
#
# ...
